# %% [markdown]
# ##### 1. Personal Info Printer

# %%
Name = input("Enter your name : ")
Age = int(input("Enter your age")) 
print(Name)
print(Age)
# Out:
# Enter your name :  Rohan
# Enter your age 35
# Rohan
# 35

# %% [markdown]
# ----

# %% [markdown]
# ##### 2. Favorite Things

# %%
Favorite_food = input("Enter your Favorite food: ")
Favorite_movie = input("Enter your Favorite movie : ")
print(Favorite_movie )
print (Favorite_food)
# Out:
# Enter your Favorite food:  rice
# Enter your Favorite movie :  rrr
# rrr
# rice

# %% [markdown]
# ----

# %% [markdown]
# ##### 3. Valid or Invalid

# %% [markdown]
# > 1name ---> this is Invaild  because , it contains first index as number
# >
# > my_name ----> this is vaild because , it contains _(underscore) not any spl. character
# >
# > total-price ---->this is  Invaild  because , it contains spl. character in between total and price(-)
# >
# > _age ----> this is vaild because , it contains _(underscore) not any spl. character at first index
# >
# > class ----> this is Invaild because ,because it contains keyword->class

# %% [markdown]
# -----

# %% [markdown]
# ##### 4. Fix the Errors

# %% [markdown]
# > 1value --->value1
# >
# > my name---->my_name or myname
# >
# > my@email ---->my_email or myemail

# %% [markdown]
# ----

# %% [markdown]
# ##### 5. Identify the Components

# %% [markdown]
# x = 10
#
# y = "Python"
#
# > Variables ----> x and y
# > Literals -----> 10 and "python"
# > Type of each literal -----> 10=int and "python=string"

# %% [markdown]
# ----

# %% [markdown]
# ##### 6. String vs Number

# %%
Name = input("Enter your name : ")
print(Name)
print("input stored as string  because , by defult is collect as string")
# Out:
# Enter your name :  rohan
# rohan
# input stored as string , because it is not int(input())

# %% [markdown]
# ----

# %% [markdown]
# ##### 7. Case Sensitivity Check

# %%
name = "Ravi"
Name = "Rahul"

print(name)
print(Name)

print("it is valid because , python is a case sensitivity language")
# Out:
# Ravi
# Rahul
# it is valid because , python is a case sensitivity language

# %% [markdown]
# ----

# %% [markdown]
# ##### 8. Student Details System

# %%
Name = input("Enter your Name : ")
Age = int(input("Enter your Age")) 
City = input("Enter your City : ")
print("studentname : " , Name)
print("Age : " , Age)
print("city : " , City)
# Out:
# Enter your Name :  Ravi
# Enter your Age 21
# Enter your City :  hyderabad
# studentname :  Ravi
# Age :  21
# city :  hyderabad

# %% [markdown]
# ---

# %% [markdown]
# ##### 9. Fancy Output

# %%
name = input("Enter your Name : ")
course = input("Enter your CourseName : ")
print("Welcome",name)
print("You are enrolled in "+ course +" course")
# Out:
# Enter your Name :  ravi
# Enter your CourseName :  python
# Welcome ravi
# You are enrolled in python course

# %% [markdown]
# ----

# %% [markdown]
# ##### 10.Keywords-Based Question

# %% [markdown]
# > class = "Python", class ----> this is Invaild  because it contains keyword->class
# >
# > def = 10 , ----> this is Invaild  because it contains keyword->def
# >
# >If = "Data Science" ----> this is valid because , it is If not if keyword
# >
# >Sum_ = 20 ---->this is vaild because , it contains _(underscore) not any spl. character at first index

# %% [markdown]
# ----

# %% [markdown]
# ##### 11. Identify Data Types

# %% [markdown]
# > a = 100 ----> it is integer data type
# >
# > b = 99.99 ----> it is float data type
# >
# > c = True  ----> it is boolean data type

# %% [markdown]
# ---

# %% [markdown]
# ##### 12. Type Function

# %%
x = 50
y = 50.0
z = False
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ---

# %% [markdown]
# ##### 13. Input Type

# %% [markdown]
# num = input("Enter a number: ")
#
# print(type(num))
#
# > the output type --> it will be in string datatype

# %% [markdown]
# ----

# %% [markdown]
# ##### 14. Integer Conversion

# %%
x = "25"
y = int(x)
print(type(y))
# Out:
# <class 'int'>

# %% [markdown]
# ---

# %% [markdown]
# ##### 15. Float Conversion

# %%
x = "10.5"
y = float(x)
print(type(y))
# Out:
# <class 'float'>

# %% [markdown]
# ----

# %% [markdown]
# ##### 16. Boolean Conversion

# %%
x = 0
y = 1
xx= bool(x)
yy=bool(y)
print(xx)
print(yy)
print(type(yy))
print(type(xx))
# Out:
# False
# True
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ---

# %% [markdown]
# ##### 17. Invalid Conversion

# %%
x = "Hello" 
y = int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 x = "Hello"
# ----> 2 y = int(x)
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# > it will not convert because , invalid literal for int()

# %% [markdown]
# ---

# %% [markdown]
# ##### 18. Reassign Type

# %% [markdown]
# x = 10
#
# x = 10.5
#
# > the final type of x is float because it's value is 10.5

# %% [markdown]
# ----

# %% [markdown]
# ##### 19. Boolean Type Check

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %% [markdown]
# ----

# %% [markdown]
# ##### 20. Store Input as Integer

# %%
age = input("Enter age: ")
print(type(int(age)))
# Out:
# Enter age:  21
# <class 'int'>

# %% [markdown]
# ----

# %% [markdown]
# ### the end
