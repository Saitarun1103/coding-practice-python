# %% [markdown]
# ### task2

# %% [markdown]
# ##### 1. Username Cleaning System

# %%
name = input("Enter username : ")
name = name.strip()
name = name.capitalize()
print(name)
# Out:
# Enter username :     ravi kumar
# Ravi kumar

# %% [markdown]
# ----

# %% [markdown]
# ##### 2. File Name Analyzer

# %%
file = "report_final.pdf" 
print("Does it end with '.pdf' :  " ,file.endswith('.pdf'))
print(file[0:-4])
# Out:
# Does it end with '.pdf' :   True
# report_final

# %% [markdown]
# ----

# %% [markdown]
# ##### 3. Text Length and Count

# %%
text = ("python programming")
print("Total number of characters : " ,len(text))
print("Number of times 'p' appears :",text.count('p'))
# Out:
# Total number of characters :  18
# Number of times 'p' appears : 2

# %% [markdown]
# ----

# %% [markdown]
# ##### 4. Search Position

# %%
text = "machine learning"
print(text.find("g"))
print(text.find("z"))
# Out:
# 15
# -1

# %% [markdown]
# ---

# %% [markdown]
# ##### 5. Replace Scenario

# %%
text = "I love Java"
print (text.replace("Java" , "python"))
# Out:
# I love python

# %% [markdown]
# ----

# %% [markdown]
# ##### 6.Case Conversion

# %%
text = "pYtHoN" 
print(text.lower())
print(text.upper())
# Out:
# python
# PYTHON

# %% [markdown]
# ---

# %% [markdown]
# ##### 7. Title Formatting

# %%
text = "data science with python" 
print(text.title())
# Out:
# Data Science With Python

# %% [markdown]
# ---

# %% [markdown]
# ##### 8. Split Operation

# %%
data = "apple,banana,grape"
print(data.split(","))
# Out:
# ['apple', 'banana', 'grape']

# %% [markdown]
# ---

# %% [markdown]
# ##### 9. Join Operation

# %%
words = ["data", "science", "rocks"] 
print(" ".join(words))
# Out:
# data science rocks

# %% [markdown]
# ---

# %% [markdown]
# ##### 10. Indexing Practice

# %%
text = "Innomatics"
print(text[0])
print(text[-1])
print(text[0:-1])
# Out:
# I
# s
# Innomatic

# %% [markdown]
# ---

# %% [markdown]
# ##### 11. Slicing Challenge

# %%
text = "DataScience" 
print(text[4:])
# Out:
# Science

# %% [markdown]
# ---

# %% [markdown]
# ##### 12. Reverse String

# %%
text = "python" 
print(text[::-1])
# Out:
# nohtyp

# %% [markdown]
# ---

# %% [markdown]
# ##### 13. Step Slicing

# %%
text = "abcdefgh" 
print(text[1:8:2])
# Out:
# bdfh

# %% [markdown]
# ----

# %% [markdown]
# ##### 14. Reverse Words Logic

# %%
text = "data science"
print(text[::-1])
# Out:
# ecneics atad

# %% [markdown]
# ----

# %% [markdown]
# ##### 15. Strip vs Replace

# %%
text = "  hello  " 
print(text.strip())
print (text.replace(" " , ""))
# Out:
# hello
# hello

# %% [markdown]
# ---

# %% [markdown]
# ##### 16. Startswith / Endswith

# %%
text = "data_science.py" 
print(text.startswith('data'))
print(text.endswith('.py'))
# Out:
# True
# True

# %% [markdown]
# ---

# %% [markdown]
# ##### 17. Character Type Check

# %%
text = "Python123" 

print ("is it alphanumeric : ",text.isalnum())
print("Is it alphabet : ",text.isalpha())
# Out:
# is it alphanumeric :  True
# Is it alphabet :  False

# %% [markdown]
# ---

# %% [markdown]
# ##### 18. Uppercase Check

# %%
text = "PYTHON" 
print(text.isupper())
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ##### 19. Lowercase Check

# %%
text = "python" 
print(text.islower())
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ##### 20. Digit Check

# %%
text = "12345" 
print(text.isdigit())
# Out:
# True

# %% [markdown]
# ----

# %% [markdown]
# ##### 21. Immutability Check

# %%
text = "hello" 
text[0] = "H" 
print(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 text = "hello"
# ----> 2 text[0] = "H"
#       3 print(text)
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# >  This happens because string does not support item assign in value

# %% [markdown]
# ---

# %% [markdown]
# ##### 22. Replace Trap

# %%
text = "banana" 
new_text = text.replace("a", "A") 
print(text) 
print(new_text)
# Out:
# banana
# bAnAnA

# %% [markdown]
# ----

# %% [markdown]
# ##### 23. Count vs Find

# %%
text = "banana" 
print(text.count('a'))
print(text.find('a'))
print(text.rindex('a'))
# Out:
# 3
# 1
# 5

# %% [markdown]
# ----

# %% [markdown]
# ##### 24. Find vs Index Difference

# %%
text = "python"
print(text.find('z'))
print(text.index('z'))
# Out:
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 3
#       1 text = "python"
#       2 print(text.find('z'))
# ----> 3 print(text.index('z'))
#
# ValueError: substring not found

# %% [markdown]
# > find()--> it finds is 'z' is present or not , so it gives -1
# > index()--> it finds index of "z" so , unable to find the index because "python" doesn't contions z

# %% [markdown]
# ----

# %% [markdown]
# ##### 25. Membership Check

# %%
text = "innomatics data science course" 
print('science' in text)
print(text.index('science'))
# Out:
# True
# 16

# %% [markdown]
# ----

# %% [markdown]
# ##### 26. Email Processing

# %%
email = "student@innomatics.ai"
email=(email.split('@'))
username=(email[0])
domain = (email[1])

print(username )
print(domain)
# Out:
# student
# innomatics.ai

# %% [markdown]
# ----

# %% [markdown]
# ##### 27. Word Count Logic

# %%
text = "python is easy to learn"
print(len(text.split()))
# Out:
# 5

# %% [markdown]
# ---

# %% [markdown]
# ##### 28. Data Cleaning Pipeline

# %%
text = "  python,data,science,python  " 
text= text.strip()
print(text.split(','))
# Out:
# ['python', 'data', 'science', 'python']

# %% [markdown]
# ----

# %% [markdown]
# ##### 29. Password Validator

# %%
password = "Data123" 
print(password.isalnum())
print(password.isalnum())
# Out:
# True
# True

# %% [markdown]
# ----

# %% [markdown]
# ##### 30. MODIFY GIVEN TEXT

# %%
text = "  python programming  "
text1=(text.strip())
text2=text1.upper()
print (text2.replace("PROGRAMMING" , "CODING"))
# Out:
# PYTHON CODING
