# %% [markdown]
# ### 📘 Daily Task – Python Set &Dictionary

# %% [markdown]
# ### Set Questions
# ##### 1. Unique Student IDs

# %%
student_ids = {101, 102, 103, 104}
print(student_ids)
print(len(student_ids))
# Out:
# {104, 101, 102, 103}
# 4

# %% [markdown]
# ---

# %% [markdown]
# ##### 2. Add a New Member

# %%
languages = {"Python", "SQL", "Java"}
languages.add("c++")
print(languages)
# Out:
# {'SQL', 'Java', 'Python', 'c++'}

# %% [markdown]
# ---

# %% [markdown]
# ##### 3. Add Multiple Values

# %%
fruits = {"apple", "banana"}
fruits.update(["orange" , "grapes"])
print(fruits)
# Out:
# {'orange', 'grapes', 'banana', 'apple'}

# %% [markdown]
# ---

# %% [markdown]
# ##### 4. Remove an Item

# %%
colors = {"red", "green", "blue"}
colors.remove("green")
print(colors)
# Out:
# {'blue', 'red'}

# %% [markdown]
# ---

# %% [markdown]
# ##### 5. Discard an Item

# %%
animals = {"cat", "dog", "rabbit"}
animals.discard("lion")
print(animals)
# Out:
# {'rabbit', 'dog', 'cat'}

# %% [markdown]
# - it will show error if not used discard , discard will skip that line of code if any error comes

# %% [markdown]
# ---

# %% [markdown]
# ##### 6. Pop an Element

# %%
cities = {"Delhi", "Mumbai", "Chennai"}
cities.pop()
print(cities)
# Out:
# {'Mumbai', 'Delhi'}

# %% [markdown]
# ---

# %% [markdown]
# ##### 7. Clear the Set

# %%
numbers = {10, 20, 30, 40}
numbers.clear()
print(numbers)
# Out:
# set()

# %% [markdown]
# ---

# %% [markdown]
# ##### 8. Union Operation

# %%
s1 = {1, 2, 3}
s2 = {3, 4, 5}
print(s1|s2)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ---

# %% [markdown]
# ##### 9. Intersection Operation

# %%
python_students = {"Ravi", "Priya", "Anu"}
ml_students = {"Anu", "Rahul", "Priya"}
print(python_students&ml_students)
# Out:
# {'Priya', 'Anu'}

# %% [markdown]
# ---

# %% [markdown]
# ##### 10. Students Enrolled Only in Python

# %%
python_students = {"Ravi", "Priya", "Anu"}
ml_students = {"Anu", "Rahul", "Priya"} 
print(python_students-ml_students)
# Out:
# {'Ravi'}

# %% [markdown]
# ---

# %% [markdown]
# ##### 11. Students Enrolled in Only One Course

# %%
python_students = {"Ravi", "Priya", "Anu"}
ml_students = {"Anu", "Rahul", "Priya"}
print(python_students^ml_students)
# Out:
# {'Ravi', 'Rahul'}

# %% [markdown]
# ----

# %% [markdown]
# ##### 12. Membership Test

# %%
courses = {"Python", "SQL", "ML"}
print("AI" in courses)
# Out:
# False

# %% [markdown]
# ---

# %% [markdown]
# ##### 13. Remove Duplicates

# %%
marks = [90, 85, 90, 78, 85, 92]
marks = set(marks)
print(marks)
# Out:
# {90, 92, 85, 78}

# %% [markdown]
# ---

# %% [markdown]
# ##### 14. Convert Set to List

# %%
colors = {"red", "blue", "green"}
colors = list(colors)
print(colors)
# Out:
# ['blue', 'red', 'green']

# %% [markdown]
# ---

# %% [markdown]
# ##### 15. Find Length

# %%
items = {"Pen", "Book", "Bag", "Bottle"}
print(len(items))
# Out:
# 4

# %% [markdown]
# ---

# %% [markdown]
# ### Dictionary Questions
# ##### 16. Employee Details

# %%
employee = {
    "id":101,
    "name":"Ravi",
    "salary":35000
}
print(employee)
# Out:
# {'id': 101, 'name': 'Ravi', 'salary': 35000}

# %% [markdown]
# ---

# %% [markdown]
# ##### 17. Add a New Key

# %%
student = {
    "name":"Asha",
    "age":20
}
student["course"]="Python"
print(student)
# Out:
# {'name': 'Asha', 'age': 20, 'course': 'Python'}

# %% [markdown]
# ----

# %% [markdown]
# ##### 18. Update Marks

# %%
marks = {
    "Math":85,
    "Science":90
}
marks['Science'] = 95
print(marks)
# Out:
# {'Math': 85, 'Science': 95}

# %% [markdown]
# ---

# %% [markdown]
# ##### 19. Remove a Key

# %%
car = {
    "brand":"Toyota",
    "year":2023,
    "color":"White"
}
del car ['color']
print(car)
# Out:
# {'brand': 'Toyota', 'year': 2023}

# %% [markdown]
# ---

# %% [markdown]
# ##### 20. Print Keys

# %%
data = {
    "A":10,
    "B":20,
    "C":30
}
print(data.keys())
# Out:
# dict_keys(['A', 'B', 'C'])

# %% [markdown]
# ---

# %% [markdown]
# ##### 21. Display All Values

# %%
employee = {
    "id": 101,
    "name": "Ravi",
    "department": "IT",
    "salary": 45000
}
print(employee.values())
# Out:
# dict_values([101, 'Ravi', 'IT', 45000])

# %% [markdown]
# ---

# %% [markdown]
# ##### 22. Display All Key-Value Pairs

# %%
employee = {
    "id": 101,
    "name": "Ravi",
    "department": "IT",
    "salary": 45000
}
print(employee.items())
print(type(items))
# Out:
# dict_items([('id', 101), ('name', 'Ravi'), ('department', 'IT'), ('salary', 45000)])
# <class 'set'>

# %% [markdown]
# ---

# %% [markdown]
# ##### 23. Check a Key

# %%
student = {
    "name":"Priya",
    "age":21
}
print(student.keys())
print('city' in student)
# Out:
# dict_keys(['name', 'age'])
# False

# %% [markdown]
# ---

# %% [markdown]
# ##### 24. Merge Dictionaries

# %%
d1 = {"a":1, "b":2}
d2 = {"c":3, "d":4}
print(d1|d2)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# ---

# %% [markdown]
# ##### 25. Dictionary Length

# %%
subjects = {
    "Python":95,
    "SQL":90,
    "ML":88,
    "AI":92
}
print(len(subjects.keys()))
# Out:
# 4

# %% [markdown]
# ---

# %% [markdown]
# ### Set + Dictionary Questions
# ##### 26. Common Subjects

# %%
student1 = {"Python", "SQL", "ML"}
student2 = {"SQL", "AI", "ML"}
print(student1&student2)
# Out:
# {'ML', 'SQL'}

# %% [markdown]
# ---

# %% [markdown]
# ##### 27. Unique Subjects

# %%
student1 = {"Python", "SQL", "ML"}
student2 = {"SQL", "AI", "ML"}
print(student1.symmetric_difference (student2))
print(student1| (student2))
# Out:
# {'AI', 'Python'}
# {'ML', 'Python', 'SQL', 'AI'}

# %% [markdown]
# ---

# %% [markdown]
# ##### 28. Classroom Attendance

# %%
attendance = {
    "Monday":{"Ravi","Anu","Priya"},
    "Tuesday":{"Anu","Rahul","Priya"}
}
print(attendance['Monday'])
print(attendance['Tuesday'])
# Out:
# {'Ravi', 'Priya', 'Anu'}
# {'Rahul', 'Priya', 'Anu'}

# %% [markdown]
# ---

# %% [markdown]
# ##### 29. Library System

# %%
library = {
    "Python":{"Ravi","Priya"},
    "SQL":{"Anu","Priya"},
    "ML":{"Rahul","Ravi"}
}
print(library['Python'])
print(library['Python']&library['ML'])
# Out:
# {'Ravi', 'Priya'}
# {'Ravi'}

# %% [markdown]
# ---

# %% [markdown]
# ##### 30. Club Registration

# %%
clubs = {
    "Coding":{"Asha","Ravi","Priya"},
    "Sports":{"Ravi","Rahul"},
    "Music":{"Priya","Anu"}
}
print(clubs['Coding'])
print(clubs['Coding'] &clubs['Sports'])
print(clubs['Coding'] |clubs['Music'])
print(len(clubs['Sports']))
# Out:
# {'Ravi', 'Asha', 'Priya'}
# {'Ravi'}
# {'Ravi', 'Anu', 'Priya', 'Asha'}
# 2
